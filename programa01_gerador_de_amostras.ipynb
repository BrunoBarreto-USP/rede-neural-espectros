# %% [markdown]
# ## Como gerar um diretório contendo os arquivos Fits

# %%
# para instalar o astropy
# !pip install astropy
from astropy.io import fits
hdul = fits.open('specObj-dr17.fits')
hdul.info()

# ver as colunas 
print(hdul[1].columns)
# Out:
# Filename: specObj-dr17.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1                1 BinTableHDU    283   5801200R x 133C   [6A, 4A, 16A, 27A, 16A, 8A, E, E, E, J, E, E, J, B, B, B, B, B, B, B, J, 22A, 19A, 19A, 22A, 20A, I, 4A, 7A, 7A, J, D, D, D, E, E, 25A, 8A, K, J, J, J, J, J, K, K, J, J, J, J, J, J, K, K, K, K, K, K, K, K, I, J, J, J, J, 5J, D, D, 6A, 21A, E, E, E, J, E, 24A, 10J, J, 10E, E, E, E, E, E, E, J, E, E, E, J, E, 5E, E, 10E, 10E, 10E, 5E, 5E, 5E, 5E, 5E, J, J, E, E, E, E, E, E, 25A, 21A, 12A, E, E, E, E, E, E, E, E, J, E, E, J, 6A, 21A, E, E, J, J, A, 5E, 5E]
# ColDefs(
#     name = 'SURVEY'; format = '6A'
#     name = 'INSTRUMENT'; format = '4A'
#     name = 'CHUNK'; format = '16A'
#     name = 'PROGRAMNAME'; format = '27A'
#     name = 'PLATERUN'; format = '16A'
#     name = 'PLATEQUALITY'; format = '8A'
#     name = 'PLATESN2'; format = 'E'
#     name = 'DEREDSN2'; format = 'E'
#     name = 'LAMBDA_EFF'; format = 'E'
#     name = 'BLUEFIBER'; format = 'J'
#     name = 'ZOFFSET'; format = 'E'
#     name = 'SNTURNOFF'; format = 'E'
#     name = 'NTURNOFF'; format = 'J'
#     name = 'SPECPRIMARY'; format = 'B'
#     name = 'SPECSDSS'; format = 'B'
#     name = 'SPECLEGACY'; format = 'B'
#     name = 'SPECSEGUE'; format = 'B'
#     name = 'SPECSEGUE1'; format = 'B'
#     name = 'SPECSEGUE2'; format = 'B'
#     name = 'SPECBOSS'; format = 'B'
#     name = 'BOSS_SPECOBJ_ID'; format = 'J'
#     name = 'SPECOBJID'; format = '22A'
#     name = 'FLUXOBJID'; format = '19A'
#     name = 'BESTOBJID'; format = '19A'
#     name = 'TARGETOBJID'; format = '22A'
#     name = 'PLATEID'; format = '20A'
#     name = 'NSPECOBS'; format = 'I'
#     name = 'FIRSTRELEASE'; format = '4A'
#     name = 'RUN2D'; format = '7A'
#     name = 'RUN1D'; format = '7A'
#     name = 'DESIGNID'; format = 'J'
#     name = 'CX'; format = 'D'
#     name = 'CY'; format = 'D'
#     name = 'CZ'; format = 'D'
#     name = 'XFOCAL'; format = 'E'
#     name = 'YFOCAL'; format = 'E'
#     name = 'SOURCETYPE'; format = '25A'
#     name = 'TARGETTYPE'; format = '8A'
#     name = 'THING_ID_TARGETING'; format = 'K'
#     name = 'THING_ID'; format = 'J'
#     name = 'PRIMTARGET'; format = 'J'
#     name = 'SECTARGET'; format = 'J'
#     name = 'LEGACY_TARGET1'; format = 'J'
#     name = 'LEGACY_TARGET2'; format = 'J'
#     name = 'SPECIAL_TARGET1'; format = 'K'
#     name = 'SPECIAL_TARGET2'; format = 'K'
#     name = 'SEGUE1_TARGET1'; format = 'J'
#     name = 'SEGUE1_TARGET2'; format = 'J'
#     name = 'SEGUE2_TARGET1'; format = 'J'
#     name = 'SEGUE2_TARGET2'; format = 'J'
#     name = 'MARVELS_TARGET1'; format = 'J'
#     name = 'MARVELS_TARGET2'; format = 'J'
#     name = 'BOSS_TARGET1'; format = 'K'
#     name = 'BOSS_TARGET2'; format = 'K'
#     name = 'EBOSS_TARGET0'; format = 'K'
#     name = 'EBOSS_TARGET1'; format = 'K'
#     name = 'EBOSS_TARGET2'; format = 'K'
#     name = 'EBOSS_TARGET_ID'; format = 'K'
#     name = 'ANCILLARY_TARGET1'; format = 'K'
#     name = 'ANCILLARY_TARGET2'; format = 'K'
#     name = 'SPECTROGRAPHID'; format = 'I'
#     name = 'PLATE'; format = 'J'
#     name = 'TILE'; format = 'J'
#     name = 'MJD'; format = 'J'
#     name = 'FIBERID'; format = 'J'
#     name = 'OBJID'; format = '5J'
#     name = 'PLUG_RA'; format = 'D'
#     name = 'PLUG_DEC'; format = 'D'
#     name = 'CLASS'; format = '6A'
#     name = 'SUBCLASS'; format = '21A'
#     name = 'Z'; format = 'E'
#     name = 'Z_ERR'; format = 'E'
#     name = 'RCHI2'; format = 'E'
#     name = 'DOF'; format = 'J'
#     name = 'RCHI2DIFF'; format = 'E'
#     name = 'TFILE'; format = '24A'
#     name = 'TCOLUMN'; format = '10J'
#     name = 'NPOLY'; format = 'J'
#     name = 'THETA'; format = '10E'
#     name = 'VDISP'; format = 'E'
#     name = 'VDISP_ERR'; format = 'E'
#     name = 'VDISPZ'; format = 'E'
#     name = 'VDISPZ_ERR'; format = 'E'
#     name = 'VDISPCHI2'; format = 'E'
#     name = 'VDISPNPIX'; format = 'E'
#     name = 'VDISPDOF'; format = 'J'
#     name = 'WAVEMIN'; format = 'E'
#     name = 'WAVEMAX'; format = 'E'
#     name = 'WCOVERAGE'; format = 'E'
#     name = 'ZWARNING'; format = 'J'
#     name = 'SN_MEDIAN_ALL'; format = 'E'
#     name = 'SN_MEDIAN'; format = '5E'
#     name = 'CHI68P'; format = 'E'
#     name = 'FRACNSIGMA'; format = '10E'
#     name = 'FRACNSIGHI'; format = '10E'
#     name = 'FRACNSIGLO'; format = '10E'
#     name = 'SPECTROFLUX'; format = '5E'
#     name = 'SPECTROFLUX_IVAR'; format = '5E'
#     name = 'SPECTROSYNFLUX'; format = '5E'
#     name = 'SPECTROSYNFLUX_IVAR'; format = '5E'
#     name = 'SPECTROSKYFLUX'; format = '5E'
#     name = 'ANYANDMASK'; format = 'J'
#     name = 'ANYORMASK'; format = 'J'
#     name = 'SPEC1_G'; format = 'E'
#     name = 'SPEC1_R'; format = 'E'
#     name = 'SPEC1_I'; format = 'E'
#     name = 'SPEC2_G'; format = 'E'
#     name = 'SPEC2_R'; format = 'E'
#     name = 'SPEC2_I'; format = 'E'
#     name = 'ELODIE_FILENAME'; format = '25A'
#     name = 'ELODIE_OBJECT'; format = '21A'
#     name = 'ELODIE_SPTYPE'; format = '12A'
#     name = 'ELODIE_BV'; format = 'E'
#     name = 'ELODIE_TEFF'; format = 'E'
#     name = 'ELODIE_LOGG'; format = 'E'
#     name = 'ELODIE_FEH'; format = 'E'
#     name = 'ELODIE_Z'; format = 'E'
#     name = 'ELODIE_Z_ERR'; format = 'E'
#     name = 'ELODIE_Z_MODELERR'; format = 'E'
#     name = 'ELODIE_RCHI2'; format = 'E'
#     name = 'ELODIE_DOF'; format = 'J'
#     name = 'Z_NOQSO'; format = 'E'
#     name = 'Z_ERR_NOQSO'; format = 'E'
#     name = 'ZWARNING_NOQSO'; format = 'J'
#     name = 'CLASS_NOQSO'; format = '6A'
#     name = 'SUBCLASS_NOQSO'; format = '21A'
#     name = 'RCHI2DIFF_NOQSO'; format = 'E'
#     name = 'Z_PERSON'; format = 'E'
#     name = 'CLASS_PERSON'; format = 'J'
#     name = 'Z_CONF_PERSON'; format = 'J'
#     name = 'COMMENTS_PERSON'; format = 'A'
#     name = 'CALIBFLUX'; format = '5E'
#     name = 'CALIBFLUX_IVAR'; format = '5E'
# )

# %%
import os
print(os.getcwd())
# aqui você verá o diretório atual do seu pc, onde o arquivo .fits foi baixado
# Out:
# d:\IC\programas_IC

# %%
import numpy as np
from astropy.io import fits
import threading
import requests
from collections import Counter
# Bibliotecas necessárias para o funcionamento do código

# %% [markdown]
# Agora vamos implementar um gerador de amostras

# %%
def gerador_de_amostras(sample_size, specobj_filename):
    catalog_file = specobj_filename
    try:
        hdul = fits.open(catalog_file)
        data = hdul[1].data  # Acessa a tabela do catálogo
        hdul.close()
        
        total_objects = len(data)
        sample_size = sample_size
        if total_objects < sample_size:
            print(f"O catálogo contém apenas {total_objects} objetos, não é possível extrair uma amostra de {sample_size}.")
        else:
            
            indices = np.random.choice(total_objects, sample_size, replace=False)
            random_sample = data[indices]
            print(f"Amostra aleatória de {sample_size} objetos extraída com sucesso.")
            # Agora você pode utilizar random_sample para suas análises
    except Exception as e:
        print(f"Erro: {e}")
    if 'CLASS' in random_sample.names:
        classes = random_sample['CLASS']
        counts = Counter(classes)
        print("Número de objetos por classe na amostra:")
        for classe, num in counts.items():
            print(f"{classe}: {num}")
    else:
        print("A coluna 'CLASS' não foi encontrada na amostra.")
    return random_sample

# %%
def baixar_espectro(target_plate, target_mjd, target_fiberid, classe, subclass,redshift, download_dir):
    plate_str = f'{target_plate:04d}'
    mjd_str = f'{target_mjd}'
    fiberid_str = f'{target_fiberid:04d}'
    classe_str = classe
    subclass_str = subclass
    redshift_str = f'{redshift:.5f}'
    spectrum_filename = f'spec-{plate_str}-{mjd_str}-{fiberid_str}-{classe_str}-{subclass_str}-{redshift_str}.fits'
    full_spectrum_path = os.path.join(download_dir, spectrum_filename)
    sdss_sas_url_base = 'https://dr17.sdss.org/optical/spectrum/view/data/format=fits/spec=lite'
    download_url = (
        f'{sdss_sas_url_base}?'
        f'plateid={plate_str}'
        f'&mjd={mjd_str}'
        f'&fiberid={fiberid_str}'
    )

    print(f"Thread {threading.current_thread().name}: Tentando baixar {spectrum_filename} de {download_url}")
    try:
        response = requests.get(download_url, stream=True)
        response.raise_for_status()  # Lança uma exceção para códigos de status ruins (4xx ou 5xx)
        with open(full_spectrum_path, 'wb') as f:
            for chunk in response.iter_content(chunk_size=8192):
                f.write(chunk)
        print(f"Thread {threading.current_thread().name}: Download de {spectrum_filename} concluído.")
    except requests.exceptions.RequestException as e:
        print(f"Thread {threading.current_thread().name}: Erro ao baixar {spectrum_filename}: {e}")
        if os.path.exists(full_spectrum_path):
            try:
                os.remove(full_spectrum_path)
            except OSError as e:
                print(f"Thread {threading.current_thread().name}: Erro ao remover arquivo incompleto {full_spectrum_path}: {e}")

def baixa_aqruivos_da_amostra_rapido(sample_size, specobj_filename,download_dir):
    amostra = gerador_de_amostras(sample_size, specobj_filename)
    os.makedirs(download_dir, exist_ok=True)
    threads = []

    for i in range(sample_size):
        target_plate = amostra['PLATE'][i]
        target_mjd = amostra['MJD'][i]
        target_fiberid = amostra['FIBERID'][i]
        classe = amostra['CLASS'][i]
        subclass = amostra['SUBCLASS'][i]
        redshift = amostra['Z'][i]
        thread = threading.Thread(target=baixar_espectro, args=(target_plate, target_mjd, target_fiberid,classe, subclass, redshift, download_dir))
        threads.append(thread)
        thread.start()

    for thread in threads:
        thread.join()

    print("\nProcesso de download paralelo concluído.")

# %%
download_dir = 'D:\sdss_spectra' # altere para o diretório desejado

# %%
for i in range(10): # baixa no total 10000 espectros, altere o range para o número desejado
    tamanho_amostra = 1000 # Defina o tamanho da amostra desejada
    catalog_file = 'specObj-dr17.fits'
    baixa_aqruivos_da_amostra_rapido(tamanho_amostra,catalog_file,download_dir)

# %%
def verificar_arquivos_repitidos(diretorio):
    #avalie o começo dos arquivos
    # e verifique se eles são iguais ex spec-0266-51602-0139-STAR-F5-0.00003.fits ver apenas 0266-51602-0139
    arquivos = os.listdir(diretorio)
    arquivos_repetidos = []
    for arquivo in arquivos:
        if arquivo.endswith('.fits'):
            prefixo = arquivo.split('-')[:4]  # Pega os primeiros 4 elementos do nome do arquivo
            prefixo_str = '-'.join(prefixo)  # Junta os elementos para formar o prefixo
            if prefixo_str in arquivos_repetidos:
                print(f"Arquivo repetido encontrado: {arquivo}")
            else:
                arquivos_repetidos.append(prefixo_str)
    return arquivos_repetidos
print("Arquivos repetidos encontrados:")
repetidos = verificar_arquivos_repitidos(download_dir)
# Out:
# Arquivos repetidos encontrados:

# %%
import matplotlib.pyplot as plt
import glob

# %%
def plot_from_directory(directory):
    # Lista todos os arquivos .fits no diretório
    
    fits_files = glob.glob(os.path.join(directory, '*.fits'))

    for fits_file in fits_files:
        # Abre o arquivo FITS
        with fits.open(fits_file) as hdul:
            # Acessa a tabela de dados
            data = hdul[1].data
            lam = 10**data['loglam']  # Converte loglam para comprimento de onda
            flux = data['flux']
            # Plota o espectro (supondo que os dados estejam na primeira coluna)
            mask = (~np.isnan(flux)) & (flux != 0)
            lam_filtrado = lam[mask]
            flux_filtrado = flux[mask]
            # Plota o espectro filtrado
# ...
            plt.figure(figsize=(10, 5))

            # --- plote normalmente ---
            plt.plot(lam_filtrado, flux_filtrado)

            # 1) grude a curva nas laterais do eixo
            plt.xlim(lam_filtrado.min(), lam_filtrado.max())  # ou plt.margins(x=0)

            # 2) reduza a margem do eixo dentro da figura
            plt.gcf().subplots_adjust(left=0.05,   # 0 = cola na borda; 0.05 dá ~5 % de margem
                                    right=0.98,  # idem na direita
                                    bottom=0.10,
                                    top=0.93)

            # 3) use tight_layout com acolchoamento mínimo
            plt.tight_layout(pad=0.1)

            # rotulagem / grade
            plt.title(f'Espectro de {os.path.basename(fits_file)}', fontsize=25)
            plt.xlabel(r'Comprimento de onda [$\mathrm{\AA}$]', fontsize=25)

            plt.ylabel(r'Fluxo $(10^{-17}\,\mathrm{erg}\,\mathrm{s}^{-1}\,\mathrm{cm}^{-2}\,\mathrm{\AA}^{-1})$', fontsize=25)

            plt.grid()

            plt.show()

# %%
def print_do_lmin_e_lmax_e_num_de_pontos(directory):
    # Lista todos os arquivos .fits no diretório
    fits_files = glob.glob(os.path.join(directory, '*.fits'))

    for fits_file in fits_files:
        # Abre o arquivo FITS
        with fits.open(fits_file) as hdul:
            # Acessa a tabela de dados
            data = hdul[1].data
            lam = 10**data['loglam']  # Converte loglam para comprimento de onda
            flux = data['flux']
            # Plota o espectro (supondo que os dados estejam na primeira coluna)
            mask = (~np.isnan(flux)) & (flux != 0)
            lam_filtrado = lam[mask]
            flux_filtrado = flux[mask]
            print(f'Arquivo: {os.path.basename(fits_file)}')
            print(f'Número de pontos: {len(flux_filtrado)}')
            print(f'Comprimento de onda mínimo: {lam_filtrado.min()}')
            print(f'Comprimento de onda máximo: {lam_filtrado.max()}')
            print('---')

print_do_lmin_e_lmax_e_num_de_pontos(download_dir)
# Out:
# Arquivo: spec-0266-51602-0070-GALAXY-STARFORMING-0.08363.fits
# Número de pontos: 3846
# Comprimento de onda mínimo: 3794.0224609375
# Comprimento de onda máximo: 9196.0205078125
# ---
# Arquivo: spec-0266-51602-0087-STAR-OB-0.00008.fits
# Número de pontos: 3847
# Comprimento de onda mínimo: 3792.27734375
# Comprimento de onda máximo: 9193.9052734375
# ---
# Arquivo: spec-0266-51602-0139-STAR-F5-0.00003.fits
# Número de pontos: 3847
# Comprimento de onda mínimo: 3789.6572265625
# Comprimento de onda máximo: 9187.5576171875
# ---
# Arquivo: spec-0266-51602-0454-GALAXY--0.12223.fits
# Número de pontos: 3844
# Comprimento de onda mínimo: 3805.397216796875
# Comprimento de onda máximo: 9219.3427734375
# ---
# Arquivo: spec-0266-51630-0134-GALAXY--0.36926.fits
# Número de pontos: 3811
# Comprimento de onda mínimo: 3823.84228515625
# Comprimento de onda máximo: 9193.9052734375
# ---
# Arquivo: spec-0266-51630-0186-GALAXY--0.09799.fits
# Número de pontos: 3809
# Comprimento de onda mínimo: 3823.84228515625
# Comprimento de onda máximo: 9189.671875
# ---
# Arquivo: spec-0266-51630-0551-GALAXY--0.18001.fits
# Número de pontos: 3839
# Comprimento de onda mínimo: 3803.644775390625
# Comprimento de onda máximo: 9204.4951171875
# ---
# Arquivo: spec-0267-51608-0246-GALAXY--0.08001.fits
# Número de pontos: 3829
# Comprimento de onda mínimo: 3804.52197265625
# Comprimento de onda máximo: 9185.439453125
# ---
# Arquivo: spec-0267-51608-0394-GALAXY--0.31530.fits
# Número de pontos: 3844
# Comprimento de onda mínimo: 3803.644775390625
# Comprimento de onda máximo: 9215.09765625
# ---
# Arquivo: spec-0267-51608-0450-STAR-M4-0.00004.fits
# Número de pontos: 3842
# Comprimento de onda mínimo: 3803.644775390625
# Comprimento de onda máximo: 9210.8544921875
# ---
# Arquivo: spec-0267-51608-0492-GALAXY-BROADLINE-0.07790.fits
# Número de pontos: 3840
# Comprimento de onda mínimo: 3803.644775390625
# Comprimento de onda máximo: 9206.61328125
# ---
# Arquivo: spec-0267-51608-0554-GALAXY--0.09422.fits
# Número de pontos: 3838
# Comprimento de onda mínimo: 3803.644775390625
# Comprimento de onda máximo: 9202.37890625
# ---
# Arquivo: spec-0268-51633-0233-GALAXY-STARFORMING-0.09004.fits
# Número de pontos: 3833
# Comprimento de onda mínimo: 3801.018798828125
# Comprimento de onda máximo: 9185.439453125
# ---
# Arquivo: spec-0268-51633-0367-GALAXY-STARFORMING-0.08059.fits
# Número de pontos: 3833
# Comprimento de onda mínimo: 3813.291748046875
# Comprimento de onda máximo: 9215.09765625
# ---
# Arquivo: spec-0268-51633-0383-GALAXY-STARFORMING-0.08910.fits
# Número de pontos: 3833
# Comprimento de onda mínimo: 3813.291748046875
# Comprimento de onda máximo: 9215.09765625
# ---
# Arquivo: spec-0268-51633-0427-GALAXY-STARFORMING-0.08192.fits
# Número de pontos: 3833
# Comprimento de onda mínimo: 3813.291748046875
# Comprimento de onda máximo: 9215.09765625
# ---
# Arquivo: spec-0268-51633-0563-GALAXY--0.07831.fits
# Número de pontos: 3827
# Comprimento de onda mínimo: 3813.291748046875
# Comprimento de onda máximo: 9202.37890625
# ---
# Arquivo: spec-0268-51633-0607-GALAXY--0.35554.fits
# Número de pontos: 3825
# Comprimento de onda mínimo: 3815.04833984375
# Comprimento de onda máximo: 9202.37890625
# ---
# Arquivo: spec-0269-51581-0012-GALAXY--0.04337.fits
# Número de pontos: 3830
# Comprimento de onda mínimo: 3806.272705078125
# Comprimento de onda máximo: 9191.78515625
# ---
# Arquivo: spec-0269-51581-0048-GALAXY--0.04634.fits
# Número de pontos: 3838
# Comprimento de onda mínimo: 3798.394775390625
# Comprimento de onda máximo: 9189.671875
# ---
# Arquivo: spec-0269-51581-0171-GALAXY--0.17640.fits
# Número de pontos: 3846
# Comprimento de onda mínimo: 3790.531005859375
# Comprimento de onda máximo: 9187.5576171875
# ---
# Arquivo: spec-0269-51581-0306-STAR-A0--0.00035.fits
# Número de pontos: 3814
# Comprimento de onda mínimo: 3815.926025390625
# Comprimento de onda máximo: 9181.2099609375
# ---
# Arquivo: spec-0269-51581-0412-GALAXY--0.09011.fits
# Número de pontos: 3858
# Comprimento de onda mínimo: 3776.591796875
# Comprimento de onda máximo: 9179.0986328125
# ---
# Arquivo: spec-0269-51910-0011-GALAXY--0.19699.fits
# Número de pontos: 3823
# Comprimento de onda mínimo: 3816.805908203125
# Comprimento de onda máximo: 9202.37890625
# ---
# Arquivo: spec-0269-51910-0206-STAR-K5-0.00014.fits
# Número de pontos: 3835
# Comprimento de onda mínimo: 3802.77001953125
# Comprimento de onda máximo: 9193.9052734375
# ---
# Arquivo: spec-
fits
# Número de pontos: 3843
# Comprimento de onda mínimo: 3804.52197265625
# Comprimento de onda máximo: 9215.09765625
# ---
# Arquivo: spec-0363-51989-0032-STAR-A0--0.00026.fits
# Número de pontos: 3833
# Comprimento de onda mínimo: 3813.291748046875
# Comprimento de onda máximo: 9215.09765625
# ---
# Arquivo: spec-0363-51989-0500-GALAXY--0.07217.fits
# Número de pontos: 3839
# Comprimento de onda mínimo: 3806.272705078125
# Comprimento de onda máximo: 9210.8544921875
# ---
# Arquivo: spec-0364-52000-0056-GALAXY-STARFORMING-0.09173.fits
# Número de pontos: 3841
# Comprimento de onda mínimo: 3803.644775390625
# Comprimento de onda máximo: 9208.736328125
# ---
# Arquivo: spec-0364-52000-0524-GALAXY-STARFORMING-0.16326.fits
# Número de pontos: 3840
# Comprimento de onda mínimo: 3805.397216796875
# Comprimento de onda máximo: 9210.8544921875
# ---
# Arquivo: spec-0364-52000-0599-GALAXY--0.16466.fits
# Número de pontos: 3824
# Comprimento de onda mínimo: 3817.68408203125
# Comprimento de onda máximo: 9206.61328125
# ---
# Arquivo: spec-0364-52000-0614-QSO--0.63422.fits
# Número de pontos: 3819
# Comprimento de onda mínimo: 3822.08154296875
# Comprimento de onda máximo: 9206.61328125
# ---
# Arquivo: spec-0366-52017-0045-STAR-M1-0.00010.fits
# Número de pontos: 3837
# Comprimento de onda mínimo: 3809.780517578125
# Comprimento de onda máximo: 9215.09765625
# ---
# Arquivo: spec-0366-52017-0092-STAR-A0--0.00067.fits
# Número de pontos: 3841
# Comprimento de onda mínimo: 3803.644775390625
# Comprimento de onda máximo: 9208.736328125
# ---
# Arquivo: spec-0366-52017-0219-GALAXY--0.07912.fits
# Número de pontos: 3830
# Comprimento de onda mínimo: 3807.150390625
# Comprimento de onda máximo: 9193.9052734375
# ---
# Arquivo: spec-0366-52017-0479-GALAXY-STARFORMING-0.09451.fits
# Número de pontos: 3846
# Comprimento de onda mínimo: 3800.142578125
# Comprimento de onda máximo: 9210.8544921875
# ---
# Arquivo: spec-0367-51997-0304-QSO--1.54624.fits
# Número de pontos: 3808
# Comprimento de onda mínimo: 3823.84228515625
# Comprimento de onda máximo: 9187.5576171875
# ---
# Arquivo: spec-0367-51997-0526-STAR-A0--0.00005.fits
# Número de pontos: 3839
# Comprimento de onda mínimo: 3806.272705078125
# Comprimento de onda máximo: 9210.8544921875
# ---
# Arquivo: spec-0367-51997-0573-GALAXY--0.13962.fits
# Número de pontos: 3831
# Comprimento de onda mínimo: 3811.53564453125
# Comprimento de onda máximo: 9206.61328125
# ---
# Arquivo: spec-0371-52078-0175-GALAXY--0.09508.fits
# Número de pontos: 3833
# Comprimento de onda mínimo: 3805.397216796875
# Comprimento de onda máximo: 9196.0205078125
# ---
# Arquivo: spec-0371-52078-0243-GALAXY-STARBURST-0.12222.fits
# Número de pontos: 3827
# Comprimento de onda mínimo: 3808.904296875
# Comprimento de onda máximo: 9191.78515625
# ---
# Arquivo: spec-0371-52078-0471-STAR-O-0.00415.fits
# Número de pontos: 3843
# Comprimento de onda mínimo: 3803.644775390625
# Comprimento de onda máximo: 9212.978515625
# ---
# Arquivo: spec-0371-52078-0569-GALAXY--0.14710.fits
# Número de pontos: 3830
# Comprimento de onda mínimo: 3812.41259765625
# Comprimento de onda máximo: 9206.61328125
# ---
# Arquivo: spec-0372-52173-0096-GALAXY-STARFORMING-0.06351.fits
# Número de pontos: 3843
# Comprimento de onda mínimo: 3798.394775390625
# Comprimento de onda máximo: 9200.2568359375
# ---
# Arquivo: spec-0372-52173-0236-STAR-M3--0.00001.fits
# Número de pontos: 3829
# Comprimento de onda mínimo: 3805.397216796875
# Comprimento de onda máximo: 9187.5576171875
# ---
# Arquivo: spec-0372-52173-0461-STAR-K7--0.00022.fits
# Número de pontos: 3839
# Comprimento de onda mínimo: 3809.780517578125
# Comprimento de onda máximo: 9219.3427734375
# ---
# Arquivo: spec-0372-52173-0549-GALAXY-BROADLINE-0.06313.fits
# Número de pontos: 3834
# Comprimento de onda mínimo: 3810.658935546875
# Comprimento de onda máximo: 9210.8544921875
# ---
# Arquivo: spec-0372-52173-0591-QSO-BROADLINE-1.66081.fits
# Número de pontos: 3824
# Comprimento de onda mínimo: 3817.68408203125
# Comprimento de onda máximo: 9206.61328125
# ---
# Arquivo: spec-0373-51788-0100-GALAXY-STARFORMING-0.09379.fits
# Número de pontos: 3845
# Comprimento de onda mínimo: 3798.394775390625
# Comprimento de onda máximo: 9204.4951171875
# ---
# Arquivo: spec-0373-51788-0153-STAR-G2-0.00004.fits
# Número de pontos: 3843
# Comprimento de onda mínimo: 3797.51904296875
# Comprimento de onda máximo: 9198.140625
# ---
# Arquivo: spec-0373-51788-0171-GALAXY-STARFORMING-0.05614.fits
# Número de pontos: 3842
# Comprimento de onda mínimo: 3797.51904296875
# Comprimento de onda máximo: 9196.0205078125
# ---
# Arquivo: spec-0373-51788-0483-GALAXY-STARFORMING-0.09900.fits
# Número de pontos: 3851
# Comprimento de onda mínimo: 3791.403076171875
# Comprimento de onda máximo: 9200.2568359375
# ---
# Arquivo: spec-0373-51788-0490-GALAXY--0.11620.fits
# Número de pontos: 3850
# Comprimento de onda mínimo: 3791.403076171875
# Comprimento de onda máximo: 9198.140625
# ---
# Arquivo: spec-0374-51791-0011-STAR-WD--0.00159.fits
# Número de pontos: 3832
# Comprimento de onda mínimo: 3815.926025390625
# Comprimento de onda máximo: 9219.3427734375
# ---
# Arquivo: spec-0374-51791-0023-GALAXY--0.14219.fits
# Número de pontos: 3835
# Comprimento de onda mínimo: 3813.291748046875
# Comprimento de onda máximo: 9219.3427734375
# ---
# Arquivo: spec-0374-51791-0120-GALAXY--0.40826.fits
# Número de pontos: 3844
# Comprimento de onda mínimo: 3798.394775390625
# Comprimento de onda máximo: 9202.37890625
# ---
# Arquivo: spec-0374-51791-0224-QSO--1.87995.fits
# Número de pontos: 3832
# Comprimento de onda mínimo: 3804.52197265625
# Comprimento de onda máximo: 9191.78515625
# ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 22
#      19             print(f'Comprimento de onda máximo: {lam_filtrado.max()}')
#      20             print('---')
# ---> 22 print_do_lmin_e_lmax_e_num_de_pontos(download_dir)
#
# Cell In[30], line 10, in print_do_lmin_e_lmax_e_num_de_pontos(directory)
#       7 with fits.open(fits_file) as hdul:
#       8     # Acessa a tabela de dados
#       9     data = hdul[1].data
# ---> 10     lam = 10**data['loglam']  # Converte loglam para comprimento de onda
#      11     flux = data['flux']
#      12     # Plota o espectro (supondo que os dados estejam na primeira coluna)
#
# KeyboardInterrupt:

# %%
# plotar dois espectros de galáxias em azul, dois de estrelas em vermelho e dois de quasares em verde, plotar um por vez

def plotar_espectros_por_classe_um_por_um(diretorio, classe):
    # Lista todos os arquivos .fits no diretório
    fits_files = glob.glob(os.path.join(diretorio, '*.fits'))
    # Filtra os arquivos pela classe desejada
    fits_files_classe = [f for f in fits_files if classe in f]
    
    for fits_file in fits_files_classe:
        # Abre o arquivo FITS
        with fits.open(fits_file) as hdul:
            # Acessa a tabela de dados
            data = hdul[1].data
            lam = 10**data['loglam']  # Converte loglam para comprimento de onda
            flux = data['flux']
            # Plota o espectro (supondo que os dados estejam na primeira coluna)
            mask = (~np.isnan(flux)) & (flux != 0)
            lam_filtrado = lam[mask]
            flux_filtrado = flux[mask]
            color = 'blue' if classe == 'GALAXY' else 'red' if classe == 'STAR' else 'green'
            plt.figure(figsize=(10, 5))
            # --- plote normalmente ---
            plt.plot(lam_filtrado, flux_filtrado, color=color)
            # 1) grude a curva nas laterais do eixo
            plt.xlim(lam_filtrado.min(), lam_filtrado.max())
            # ou plt.margins(x=0)
            # 2) reduza a margem do eixo dentro da figura
            plt.gcf().subplots_adjust(left=0.05,   # 0 = cola na borda; 0.05 dá ~5 % de margem
                                    right=0.98,  # idem na direita
                                    bottom=0.10,
                                    top=0.93)
            # 3) use tight_layout com acolchoamento mínimo
            plt.tight_layout(pad=0.1)
            # rotulagem / grade
            plt.title(f'Espectro de objeto da classe {classe}', fontsize=26)
            plt.xlabel(r'Comprimento de onda [$\mathrm{\AA}$]', fontsize=26)
            plt.ylabel(r'Fluxo $(10^{-17}\,\mathrm{erg}\,\mathrm{s}^{-1}\,\mathrm{cm}^{-2}\,\mathrm{\AA}^{-1})$', fontsize=26)
            plt.tick_params(axis='both', which='major', labelsize=26)
            plt.grid()
            plt.show()

# %%
plotar_espectros_por_classe_um_por_um(download_dir, 'STAR')

# %%
plot_from_directory(download_dir)
